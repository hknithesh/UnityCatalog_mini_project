# %%
#list the mounts
display(dbutils.fs.mounts())

# %%
raw_folder_path = '/mnt/azuredatastorageacc1425/raw'
processed_folder_path = '/mnt/azuredatastorageacc1425/processed'
presentation_folder_path = '/mnt/azuredatastorageacc1425/presentation'

# %%
# raw_folder_path = 'abfss://raw@azuredatastorageacc1425.dfs.core.windows.net/'
# processed_folder_path = 'abfss://processed@azuredatastorageacc1425.dfs.core.windows.net/'
# presentation_folder_path = 'abfss://presentation@azuredatastorageacc1425.dfs.core.windows.net/'
