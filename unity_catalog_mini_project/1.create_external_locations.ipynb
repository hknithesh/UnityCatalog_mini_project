-- %%
--create bronze external connection
CREATE EXTERNAL LOCATION bronze
URL 'abfss://bronze@azuredatastorageacc1425.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `demo-credential`);

-- %%
--create bronze external connection
CREATE EXTERNAL LOCATION silver
URL 'abfss://silver@azuredatastorageacc1425.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `demo-credential`);

-- %%
--create bronze external connection
CREATE EXTERNAL LOCATION gold
URL 'abfss://gold@azuredatastorageacc1425.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `demo-credential`);

-- %%
DESC EXTERNAL LOCATION bronze;

-- %%
DESC EXTERNAL LOCATION silver;

-- %%
DESC EXTERNAL LOCATION gold;

-- %%
%fs
ls abfss://bronze@azuredatastorageacc1425.dfs.core.windows.net/
