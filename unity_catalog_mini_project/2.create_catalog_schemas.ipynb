-- %%
--create catalog
--CREATE CATALOG IF NOT EXISTS formula1_dev;

-- %%
--create bronze schema
USE CATALOG formula1_dev;
CREATE SCHEMA IF NOT EXISTS bronze MANAGED LOCATION "abfss://bronze@azuredatastorageacc1425.dfs.core.windows.net/";

-- %%
--create silver schema
USE CATALOG formula1_dev;
CREATE SCHEMA IF NOT EXISTS silver MANAGED LOCATION "abfss://silver@azuredatastorageacc1425.dfs.core.windows.net/";

-- %%
--create gold schema
USE CATALOG formula1_dev;
CREATE SCHEMA IF NOT EXISTS gold MANAGED LOCATION "abfss://gold@azuredatastorageacc1425.dfs.core.windows.net/";
